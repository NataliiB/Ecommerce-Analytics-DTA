# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
file_path = './../data/processed/Ecommerce_final.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#       CID         TID  Gender     Age Group        Purchase Date  \
# 0  943146  5876328741  Female         25-45  2023-08-30 20:27:08
# 1  180079  1018503182    Male         25-45  2024-02-23 09:33:46
# 2  337580  3814082218   Other  60 and above  2022-03-06 09:09:50
# 3  180333  1395204173   Other  60 and above  2020-11-04 04:41:57
# 4  447553  8009390577    Male         18-25  2022-05-31 17:00:32
#
#    Product Category Discount Availed    Discount Name  Discount Amount (INR)  \
# 0       Electronics              Yes        FESTIVE50                  64.30
# 1       Electronics              Yes  SEASONALOFFER21                 175.19
# 2          Clothing              Yes  SEASONALOFFER21                 211.54
# 3  Sports & Fitness               No      No Discount                   0.00
# 4  Sports & Fitness              Yes         WELCOME5                 439.92
#
#    Gross Amount   Net Amount Purchase Method   Location  is_discount_overflow
# 0    725.304000   661.004000     Credit Card  Ahmedabad                 False
# 1   4638.991875  4463.801875     Credit Card  Bangalore                 False
# 2   1986.372575  1774.832575     Credit Card      Delhi                 False
# 3   5695.612650  5695.612650      Debit Card      Delhi                 False
# 4   2292.651500  1852.731500     Credit Card      Delhi                 False

# %%
df['Age Group'].value_counts(normalize=True)
# Out:
# Age Group
# 25-45           0.400182
# 18-25           0.298745
# 45-60           0.201891
# under 18        0.050382
# 60 and above    0.048800
# Name: proportion, dtype: float64

# %%
df['Age Group'] = pd.Categorical(
    df['Age Group'], 
    categories=['under 18', '18-25', '25-45', '45-60', '60 and above'],
    ordered=True
)
df_final = pd.get_dummies(df, columns=["Age Group"], drop_first=True)

# %%
df_final.head()
# Out:
#       CID         TID  Gender        Purchase Date  Product Category  \
# 0  943146  5876328741  Female  2023-08-30 20:27:08       Electronics
# 1  180079  1018503182    Male  2024-02-23 09:33:46       Electronics
# 2  337580  3814082218   Other  2022-03-06 09:09:50          Clothing
# 3  180333  1395204173   Other  2020-11-04 04:41:57  Sports & Fitness
# 4  447553  8009390577    Male  2022-05-31 17:00:32  Sports & Fitness
#
#   Discount Availed    Discount Name  Discount Amount (INR)  Gross Amount  \
# 0              Yes        FESTIVE50                  64.30    725.304000
# 1              Yes  SEASONALOFFER21                 175.19   4638.991875
# 2              Yes  SEASONALOFFER21                 211.54   1986.372575
# 3               No      No Discount                   0.00   5695.612650
# 4              Yes         WELCOME5                 439.92   2292.651500
#
#     Net Amount Purchase Method   Location  is_discount_overflow  \
# 0   661.004000     Credit Card  Ahmedabad                 False
# 1  4463.801875     Credit Card  Bangalore                 False
# 2  1774.832575     Credit Card      Delhi                 False
# 3  5695.612650      Debit Card      Delhi                 False
# 4  1852.731500     Credit Card      Delhi                 False
#
#    Age Group_18-25  Age Group_25-45  Age Group_45-60  Age Group_60 and above
# 0            False             True            False                   False
# 1            False             True            False                   False
# 2            False            False            False                    True
# 3            False            False            False                    True
# 4             True            False            False                   False

# %%
X_cols = [col for col in df_final.columns if "Age Group_" in col]
X = df_final[X_cols]
y = df['Gross Amount']

# %%
model_raw = LinearRegression()
model_raw.fit(X,y)
y_pred_raw = model_raw.predict(X)

# %%
print("Intercept (середня витрата для <18):", model_raw.intercept_)

coef = pd.Series(model_raw.coef_, index=X.columns)
print("\nКоефіцієнти для кожної вікової групи (відносно <18):")
print(coef)
# Out:
# Intercept (середня витрата для <18): 3026.510347257321
#
# Коефіцієнти для кожної вікової групи (відносно <18):
# Age Group_18-25          -41.829435
# Age Group_25-45           14.577409
# Age Group_45-60          -34.110870
# Age Group_60 and above    -0.498505
# dtype: float64

# %%
mse = mean_squared_error(y, y_pred_raw)
r2 = r2_score(y, y_pred_raw)
print("\nMSE:", mse)
print("R²:", r2)
# Out:
# MSE: 2952293.2058233977
# R²: 0.00022297369370594122

# %%
import statsmodels.api as sm

# %%
X = df_final[X_cols].astype(int)

# 2️⃣ Додаємо константу для intercept
X_sm = sm.add_constant(X)
# 3️⃣ Створюємо та навчаємо модель OLS
model_sm = sm.OLS(y, X_sm).fit()

# 4️⃣ Виводимо тільки p-values
print("P-values для вікових груп (відносно <18):")
print(model_sm.pvalues)
# Out:
# P-values для вікових груп (відносно <18):
# const                     0.000000
# Age Group_18-25           0.235870
# Age Group_25-45           0.673850
# Age Group_45-60           0.349878
# Age Group_60 and above    0.991453
# dtype: float64

# %%
X
# Out:
#        Age Group_18-25  Age Group_25-45  Age Group_45-60  \
# 0                    0                1                0
# 1                    0                1                0
# 2                    0                0                0
# 3                    0                0                0
# 4                    1                0                0
# ...                ...              ...              ...
# 54995                0                1                0
# 54996                1                0                0
# 54997                0                0                1
# 54998                0                0                1
# 54999                0                1                0
#
#        Age Group_60 and above
# 0                           0
# 1                           0
# 2                           1
# 3                           1
# 4                           0
# ...                       ...
# 54995                       0
# 54996                       0
# 54997                       0
# 54998                       0
# 54999                       0
#
# [55000 rows x 4 columns]

# %%
#Подивимось які зі зв'язків інших колонок з Gross Amount не є випадковими

# %%
drop_cols = ['Gross Amount', 'CID', 'TID', 'Purchase Date']

X = df_final.drop(columns=drop_cols)
y = df_final['Gross Amount'].astype(float)

# %%
categorical_cols = ['Gender',
                    'Product Category',
                    'Discount Availed',
                    'Discount Name',
                    'Purchase Method',
                    'Location']

# %%
numeric_cols = [col for col in numeric_cols if col != 'Gross Amount']
df_new = df_final[numeric_cols]
df_new.head()

# %%
X = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# %%
bool_cols = X.select_dtypes(include='bool').columns
X[bool_cols] = X[bool_cols].astype(int)

# %%
X_sm = sm.add_constant(X)
model_sm = sm.OLS(y, X_sm).fit()

# %%
print("P-values для всіх змінних:")
significant_vars = model_sm.pvalues[model_sm.pvalues < 0.05]
significant_vars
# Out:
# P-values для всіх змінних:
# const                        1.626091e-161
# Discount Amount (INR)         0.000000e+00
# Net Amount                    0.000000e+00
# Age Group_18-25               2.161934e-02
# Age Group_45-60               3.755546e-02
# Gender_Male                   3.119110e-02
# Product Category_Clothing     3.773270e-02
# Discount Availed_Yes          2.988961e-59
# Discount Name_No Discount    5.293314e-150
# dtype: float64
