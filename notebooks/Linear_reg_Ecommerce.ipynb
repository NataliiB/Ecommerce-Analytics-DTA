# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

file_path = './../data/processed/Ecommerce_final.csv'
df = pd.read_csv(file_path)

df['Age Group'] = pd.Categorical(
    df['Age Group'], 
    categories=['under 18', '18-25', '25-45', '45-60', '60 and above'],
    ordered=True
)

X1 = pd.get_dummies(
    df[['Age Group']],
    drop_first=True
)
y = df['Gross Amount']

model = LinearRegression()
model.fit(X1,y)
y_pred_raw = model.predict(X1)

for col, coef in zip(X1.columns, model.coef_):
    print(f"{col}: {coef:.2f}")

print("Intercept (base group 'under 18'):", model.intercept_)

r2 = r2_score(y, y_pred_raw)
print(f"R-squared: {r2:.4f}")
# Out:
# Age Group_18-25: -41.83
# Age Group_25-45: 14.58
# Age Group_45-60: -34.11
# Age Group_60 and above: -0.50
# Intercept (base group 'under 18'): 3026.510347257321
# R-squared: 0.0002

# %%
import statsmodels.api as sm

X1_with_const = sm.add_constant(X1)

model = sm.OLS(y, X1_with_const.astype(float)).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Gross Amount   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     3.066
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):             0.0155
# Time:                        23:03:05   Log-Likelihood:            -4.8774e+05
# No. Observations:               55000   AIC:                         9.755e+05
# Df Residuals:                   54995   BIC:                         9.755e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   3026.5103     32.642     92.717      0.000    2962.531    3090.490
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
age_map = {
    'under 18': 16,
    '18-25': 21,
    '25-45': 35,
    '45-60': 52,
    '60 and above': 65
}
df['Age_numeric'] = df['Age Group'].map(age_map)

X3 = df[['Age_numeric']]
y = df['Gross Amount']

model = LinearRegression()
model.fit(X3, y)
y_pred = model.predict(X3)

plt.figure(figsize=(8,5))
plt.scatter(X3, y, alpha=0.3)
plt.plot(X3, y_pred, color='orange') 
plt.xlabel("Age")
plt.ylabel("Gross Amount")
plt.title("Linear Regression (sklearn): Age vs Gross Amount")
plt.tight_layout()
plt.savefig("./../visuals/charts/Linear_Regression_Age_vs_Gross_Amount.png")
plt.show()
plt.close()

# R²
from sklearn.metrics import r2_score
print("R²:", r2_score(y, y_pred))
# Out:
# R²: 5.485570807706175e-06

# %%
#Let's see which of the other columns' relationships to Gross Amount are not accidental.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import seaborn as sns


X_full = pd.get_dummies(df[['Age Group', 'Location', 'Purchase Method', 'Gender', 
                            'Product Category', 'Discount Availed']], drop_first=True)

y = df['Gross Amount']

X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(
    X_full, y, test_size=0.2, random_state=42
)

rf_full = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42, n_jobs=-1)
rf_full.fit(X_train_f, y_train_f)

importances = rf_full.feature_importances_
feature_names = X_full.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances}).sort_values(by='Importance', ascending=False)

df = feature_importance_df.head(15).sort_values("Importance", ascending=False)

plt.figure(figsize=(10, 8))

sns.barplot(
    x="Importance",
    y="Feature",
    data=df,
    palette = sns.light_palette("#1f77b4", n_colors=len(df),
                            reverse=True)
)

plt.title("Full feature rating", fontsize=14, fontweight="bold")
plt.xlabel("Importance")
plt.ylabel("")
plt.tight_layout()
plt.savefig("./../visuals/charts/Full_feature_rating.png", dpi=300)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_28864\3514267365.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
